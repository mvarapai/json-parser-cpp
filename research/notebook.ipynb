# %% [markdown]
# # Jupyter notebook to research some technical aspects of the program

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.arange(0, 5, 1)

ax = plt.plot(t, 5.7 * t, 'go-')
plt.show()
